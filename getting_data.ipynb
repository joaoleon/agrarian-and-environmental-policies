# %% [markdown]
# # Análise exploratória dos dados legislativos referentes às áreas de Agricultura e Meio Ambiente, no Brasil, durante o Governo de Jair Messias Bolsonaro (2019/2022)

# %%
# Importando pacos e bibliotecas

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Encapsulando os arquivos em objetos

ano_2019 = r"C:\Users\joaol\Downloads\proposicoesTemas-2019.csv"
ano_2020 = r"C:\Users\joaol\Downloads\proposicoesTemas-2020.csv"
ano_2021 = r"C:\Users\joaol\Downloads\proposicoesTemas-2021.csv"
ano_2022 = r"C:\Users\joaol\Downloads\proposicoesTemas-2022.csv"

# %%
# Lendo nossos arquivos como DataFrames

arquivo_2019 = pd.read_csv(ano_2019, sep=';')
arquivo_2020 = pd.read_csv(ano_2020, sep=';')
arquivo_2021 = pd.read_csv(ano_2021, sep=';')
arquivo_2022 = pd.read_csv(ano_2022, sep=';')

# %%
# Unindo nossos DataFrames

prop_legislativas = [arquivo_2019, arquivo_2020, arquivo_2021, arquivo_2022]
df_2019_2022 = pd.concat(prop_legislativas)

# %%
# Visualizando os dados até aqui

df_2019_2022.sample(15)
# Out:
#                                            uriProposicao siglaTipo  numero  \
# 2538   https://dadosabertos.camara.leg.br/api/v2/prop...       INC     268
# 9887   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC    1090
# 6058   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC     656
# 5808   https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2862
# 5450   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC     534
# 15007  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    4606
# 7696   https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2314
# 13297  https://dadosabertos.camara.leg.br/api/v2/prop...       PDL     710
# 7914   https://dadosabertos.camara.leg.br/api/v2/prop...       INC     793
# 1121   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC      32
# 4209   https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2239
# 13923  https://dadosabertos.camara.leg.br/api/v2/prop...       RIC    1381
# 7676   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC     758
# 11638  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    5418
# 570    https://dadosabertos.camara.leg.br/api/v2/prop...        PL     298
#
#         ano  codTema                                         tema  relevancia
# 2538   2021       70                Finanças Públicas e Orçamento           0
# 9887   2019       35                     Arte, Cultura e Religião           0
# 6058   2021       46                                     Educação           0
# 5808   2019       43             Direito Penal e Processual Penal           0
# 5450   2019       56                                        Saúde           0
# 15007  2020       44                  Direitos Humanos e Minorias           0
# 7696   2021       70                Finanças Públicas e Orçamento           0
# 13297  2019       34                        Administração Pública           0
# 7914   2021       64  Agricultura, Pecuária, Pesca e Extrativismo           0
# 1121   2019       64  Agricultura, Pecuária, Pesca e Extrativismo           0
# 4209   2019       72             Homenagens e Datas Comemorativas           0
# 13923  2021       61              Viação, Transporte e Mobilidade           0
# 7676   2019       40                                     Economia           0
# 11638  2019       44                  Direitos Humanos e Minorias           0
# 570    2019       44                  Direitos Humanos e Minorias           0

# %%
# Como são classificadas as iniciativas legislativas?

df_2019_2022['tema'].value_counts()
# Out:
# Saúde                                          6946
# Direitos Humanos e Minorias                    6099
# Administração Pública                          5595
# Finanças Públicas e Orçamento                  4974
# Trabalho e Emprego                             3290
# Educação                                       3121
# Defesa e Segurança                             2496
# Economia                                       2317
# Viação, Transporte e Mobilidade                2232
# Direito Penal e Processual Penal               2091
# Comunicações                                   2087
# Agricultura, Pecuária, Pesca e Extrativismo    1941
# Meio Ambiente e Desenvolvimento Sustentável    1920
# Indústria, Comércio e Serviços                 1867
# Previdência e Assistência Social               1709
# Energia, Recursos Hídricos e Minerais          1560
# Direito e Defesa do Consumidor                 1305
# Homenagens e Datas Comemorativas               1061
# Direito Civil e Processual Civil               1045
# Cidades e Desenvolvimento Urbano                909
# Arte, Cultura e Religião                        754
# Relações Internacionais e Comércio Exterior     691
# Ciência, Tecnologia e Inovação                  608
# Política, Partidos e Eleições                   596
# Processo Legislativo e Atuação Parlamentar      571
# Esporte e Lazer                                 466
# Direito e Justiça                               329
# Estrutura Fundiária                             275
# Turismo                                         242
# Direito Constitucional                          151
# Ciências Sociais e Humanas                        6
# Ciências Exatas e da Terra                        3
# Name: tema, dtype: int64

# %%
# Selecionando as propostas legislativas relacionadas aos temas de Meio Ambiente e Agricultura

meio_ambiente = df_2019_2022[df_2019_2022['tema'] == 'Meio Ambiente e Desenvolvimento Sustentável']
agricultura = df_2019_2022[df_2019_2022['tema'] == 'Agricultura, Pecuária, Pesca e Extrativismo']

# %%
# Unindo os dados legislativos sobre Meio Ambiente e Agricultura

uniao = [meio_ambiente, agricultura]
meio_ambiente_agricultura = pd.concat(uniao)

meio_ambiente_agricultura.sample(10)
# Out:
#                                            uriProposicao siglaTipo  numero  \
# 8517   https://dadosabertos.camara.leg.br/api/v2/prop...        PL    2566
# 4609   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC     278
# 16704  https://dadosabertos.camara.leg.br/api/v2/prop...       RIC    1423
# 4327   https://dadosabertos.camara.leg.br/api/v2/prop...        PL     988
# 14484  https://dadosabertos.camara.leg.br/api/v2/prop...       INC    1439
# 5346   https://dadosabertos.camara.leg.br/api/v2/prop...       RIC     554
# 14132  https://dadosabertos.camara.leg.br/api/v2/prop...        PL    6418
# 11565  https://dadosabertos.camara.leg.br/api/v2/prop...       PDL     655
# 6100   https://dadosabertos.camara.leg.br/api/v2/prop...        PL    1877
# 4322   https://dadosabertos.camara.leg.br/api/v2/prop...        PL    1311
#
#         ano  codTema                                         tema  relevancia
# 8517   2022       48  Meio Ambiente e Desenvolvimento Sustentável           0
# 4609   2022       48  Meio Ambiente e Desenvolvimento Sustentável           0
# 16704  2020       48  Meio Ambiente e Desenvolvimento Sustentável           0
# 4327   2022       48  Meio Ambiente e Desenvolvimento Sustentável           0
# 14484  2021       64  Agricultura, Pecuária, Pesca e Extrativismo           0
# 5346   2021       48  Meio Ambiente e Desenvolvimento Sustentável           0
# 14132  2019       64  Agricultura, Pecuária, Pesca e Extrativismo           0
# 11565  2019       64  Agricultura, Pecuária, Pesca e Extrativismo           0
# 6100   2021       48  Meio Ambiente e Desenvolvimento Sustentável           0
# 4322   2021       64  Agricultura, Pecuária, Pesca e Extrativismo           0

# %%
# Organizando os dados

columns = ['level_0', 'index', 'relevancia']
df = meio_ambiente_agricultura.drop(columns=columns)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 4
#       1 # Organizando os dados
#       3 columns = ['level_0', 'index', 'relevancia']
# ----> 4 df = meio_ambiente_agricultura.drop(columns=columns)
#       5 df
#
# File c:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\joaol\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['level_0', 'index'] not found in axis"

# %%
# Como estão distribuidas as proposições legislativas?

visualizacao = df['siglaTipo'].value_counts()
visualizacao

# %%
plt.plot(kind='bar', rot=45, data=visualizacao[''])

plt.xlabel('Tipo de Inciativa Legislativa')
plt.ylabel('Frequência')
plt.title('Distribuição de inciativas legislativas sobre Meio Ambiente e Agricultura (2019/2022)')

plt.show()

# %%
frequencia  = visualizacao.to_frame()

# %%
frequencia.bar()

# %% [markdown]
# meio_ambiente_agricultura
